# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from __future__ import division

# %%
df=pd.read_csv('C:/Users/omarp/Downloads/cluster.csv')

# %%
df.head()
# Out:
#          Equipo  Goles  Tiros  Tiros_buenos  Faltas  Corners  Amarillas  Rojas
# 0    Man United      2      8             6      11        2          2      0
# 1   Bournemouth      2     12             4      11        7          1      0
# 2        Fulham      0     15             6       9        5          1      0
# 3  Huddersfield      0      6             1       9        2          2      0
# 4     Newcastle      1     15             2      11        3          2      0

# %%
df=df.groupby(['Equipo']).mean()
df.reset_index(inplace=True)

# %%
var=[x for x in df.columns if x!='Equipo']

# %%
X = df[var].copy()

# %%
scaler = StandardScaler()
scaler.fit(X)
Xs = pd.DataFrame(scaler.transform(X),columns=X.columns)

# %%
Xs.head()
# Out:
#       Goles     Tiros  Tiros_buenos    Faltas   Corners  Amarillas     Rojas
# 0  0.761029 -0.198741      0.006099  0.555323  0.857641   1.679352  0.189993
# 1 -0.192922 -0.003552      0.059854  0.989713 -0.423766   0.423516 -0.572605
# 2 -0.226311 -0.636533     -0.428292 -1.442871 -0.109300   0.244921 -0.375806
# 3 -0.774832 -0.851449     -1.013050  1.174232 -1.076241  -0.537495  1.321590
# 4 -0.409151 -1.368839     -1.196831 -0.205052 -1.192274   0.896935 -1.507403

# %%
prin = ['prin'+str(comp) for comp in range(1,len(var)+1)]
pca = PCA()
pca.fit(Xs)
Xpca = pd.DataFrame(pca.transform(Xs), columns=prin)
Xpca.head()
# Out:
#       prin1     prin2     prin3     prin4     prin5     prin6     prin7
# 0 -0.026869  0.808277 -1.702696  0.691146  0.671881  0.186292 -0.043940
# 1 -0.613863  0.063811 -0.723555 -0.818248 -0.215893  0.292998  0.027332
# 2 -0.203273 -1.288666  0.171928  1.044321  0.096398 -0.301642  0.111525
# 3 -2.039877  0.999145  1.242725 -0.258766  0.014440  0.357302 -0.160103
# 4 -1.885428 -1.884785 -0.713727  0.174913  0.087511  0.580284 -0.149027

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.60719708, 0.78755731, 0.91051913, 0.95551109, 0.98342808,
#        0.99538313, 1.        ])

# %%
sns.lmplot('prin1','prin2',data=Xpca, fit_reg=False)

# %%
lst_in = []
for k in range(2,10):
    cl = KMeans(n_clusters=k)
    cl.fit(X)
    lst_in.append(cl.inertia_)

# %%
plt.plot(range(2,10),lst_in,marker='o')

# %%
gm = GaussianMixture(n_components=6)
gm.fit(Xs)
Xs['clus'] = gm.predict(Xs)
Xs.head()
# Out:
#       Goles     Tiros  Tiros_buenos    Faltas   Corners  Amarillas     Rojas  \
# 0  0.761029 -0.198741      0.006099  0.555323  0.857641   1.679352  0.189993
# 1 -0.192922 -0.003552      0.059854  0.989713 -0.423766   0.423516 -0.572605
# 2 -0.226311 -0.636533     -0.428292 -1.442871 -0.109300   0.244921 -0.375806
# 3 -0.774832 -0.851449     -1.013050  1.174232 -1.076241  -0.537495  1.321590
# 4 -0.409151 -1.368839     -1.196831 -0.205052 -1.192274   0.896935 -1.507403
#
#    clus
# 0     5
# 1     5
# 2     0
# 3     3
# 4     0

# %%
Xpca=Xpca.merge(Xs[['clus']],left_index=True,right_index=True, how='inner')

# %%
sns.lmplot('prin1','prin2',data=Xpca, fit_reg=False, hue='clus')

# %%
df=df.merge(Xs[['clus']],left_index=True,right_index=True, how='inner')

# %%
df.sort_values(['clus'])
# Out:
#               Equipo     Goles      Tiros  Tiros_buenos     Faltas   Corners  \
# 16           Norwich  1.000000  11.695652      4.043478   9.782609  4.565217
# 2        Bournemouth  1.245902  11.131148      3.868852   9.049180  5.049180
# 4            Burnley  1.163934   9.622951      3.114754  10.196721  4.131148
# 5            Cardiff  0.894737  10.973684      3.315789  10.105263  4.421053
# 21          West Ham  1.300000  11.316667      4.266667   9.400000  4.983333
# 17  Sheffield United  1.086957  10.130435      3.304348  10.869565  5.478261
# 13          Man City  2.606557  18.737705      6.934426   9.180328  7.803279
# 12         Liverpool  2.350000  15.350000      6.033333   8.300000  6.433333
# 11         Leicester  1.622951  13.622951      5.049180   9.475410  5.721311
# 19         Tottenham  1.688525  13.409836      4.803279   9.901639  5.065574
# 18       Southampton  1.213115  12.540984      4.377049  11.491803  5.032787
# 8            Everton  1.311475  13.163934      4.459016  11.590164  5.885246
# 20           Watford  1.180328  11.622951      3.688525  11.491803  4.672131
# 7     Crystal Palace  1.196721  11.622951      3.606557  10.393443  5.016393
# 3           Brighton  1.000000  10.688525      3.295082  11.475410  4.229508
# 15         Newcastle  1.049180  10.885246      3.524590  10.360656  4.163934
# 10      Huddersfield  0.578947  10.526316      3.105263  11.052632  4.263158
# 9             Fulham  0.894737  11.921053      3.921053  11.131579  4.236842
# 6            Chelsea  1.672131  16.180328      5.426230   9.295082  5.868852
# 0            Arsenal  1.688525  12.032787      4.295082  10.901639  5.868852
# 1        Aston Villa  1.260870  12.434783      4.347826  11.304348  4.782609
# 14        Man United  1.655738  14.081967      5.836066  11.295082  5.311475
# 22            Wolves  1.327869  12.475410      4.032787  10.852459  5.278689
#
#     Amarillas     Rojas  clus
# 16   1.956522  0.043478     0
# 2    1.737705  0.049180     0
# 4    1.901639  0.016393     0
# 5    1.710526  0.026316     0
# 21   1.683333  0.033333     0
# 17   1.869565  0.043478     0
# 13   1.393443  0.049180     1
# 12   1.000000  0.050000     1
# 11   1.295082  0.081967     2
# 19   1.770492  0.098361     2
# 18   1.721311  0.081967     2
# 8    1.573770  0.098361     2
# 20   2.065574  0.114754     2
# 7    1.524590  0.049180     3
# 3    1.540984  0.098361     3
# 15   1.524590  0.065574     3
# 10   1.447368  0.105263     3
# 9    1.789474  0.052632     3
# 6    1.475410  0.000000     4
# 0    2.098361  0.065574     5
# 1    1.782609  0.043478     5
# 14   1.918033  0.065574     5
# 22   1.770492  0.049180     5

# %%
df.to_csv('clus.csv')
